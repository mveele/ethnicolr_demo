# %% [markdown]
# <a href="https://colab.research.google.com/github/mveele/ethnicolr_demo/blob/main/ethnicolr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip --trusted-host pypi.org --trusted-host files.pythonhosted.org install ethnicolr -q

# %%
import pandas as pd
from ethnicolr import pred_wiki_ln, pred_wiki_name

names = [
            {"last": "smith", "first": "john"},
            {"last": "veele", "first": "mitchell"},


        ]
df = pd.DataFrame(names)
df
# Out:
#     last     first
# 0  smith      john
# 1  veele  mitchell

# %%
odf = pred_wiki_name(df, 'last', 'first')
odf.T
# Out:
#                                                              0  \
# last                                                     smith
# first                                                     john
# __name                                              Smith John
# Asian,GreaterEastAsian,EastAsian                      0.002387
# Asian,GreaterEastAsian,Japanese                       0.000988
# Asian,IndianSubContinent                              0.002318
# GreaterAfrican,Africans                                0.00126
# GreaterAfrican,Muslim                                 0.000592
# GreaterEuropean,British                               0.933225
# GreaterEuropean,EastEuropean                          0.000999
# GreaterEuropean,Jewish                                0.018743
# GreaterEuropean,WestEuropean,French                   0.023357
# GreaterEuropean,WestEuropean,Germanic                 0.002309
# GreaterEuropean,WestEuropean,Hispanic                  0.00396
# ...
